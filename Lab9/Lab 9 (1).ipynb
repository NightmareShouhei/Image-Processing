# %%
#Hamza ALsihati
#2230006810
#8MA1
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Images/Erosion.jpg', 0)
_, binary = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

kernel3 = np.ones((3, 3), np.uint8)
kernel7 = np.ones((7, 7), np.uint8)
kernel11 = np.ones((11, 11), np.uint8)

eroded3 = cv2.erode(binary, kernel3, iterations=1)
eroded7 = cv2.erode(binary, kernel7, iterations=1)
eroded11 = cv2.erode(binary, kernel11, iterations=1)

plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.imshow(eroded3, 'gray')
plt.title('Eroded 3x3')
plt.subplot(2, 2, 2)
plt.imshow(eroded7, 'gray')
plt.title('Eroded 7x7')
plt.subplot(2, 2, 3)
plt.imshow(eroded11, 'gray')
plt.title('Eroded 11x11')
plt.show()

# %%
img = cv2.imread('Images/Erosion.jpg', 0)
_, binary = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

kernel3 = np.ones((3, 3), np.uint8)
kernel7 = np.ones((7, 7), np.uint8)
kernel11 = np.ones((11, 11), np.uint8)

dilated3 = cv2.dilate(binary, kernel3, iterations=1)
dilated7 = cv2.dilate(binary, kernel7, iterations=1)
dilated11 = cv2.dilate(binary, kernel11, iterations=1)

plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.imshow(dilated3, 'gray')
plt.title('Dilated 3x3')
plt.subplot(2, 2, 2)
plt.imshow(dilated7, 'gray')
plt.title('Dilated 7x7')
plt.subplot(2, 2, 3)
plt.imshow(dilated11, 'gray')
plt.title('Dilated 11x11')
plt.show()

# %%
img = cv2.imread('Images/Open_Closing.jpg', 0)
_, binary = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

kernel = np.ones((5, 5), np.uint8)
opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(binary, 'gray')
plt.title('Original')
plt.subplot(1, 2, 2)
plt.imshow(opening, 'gray')
plt.title('After Opening')
plt.show()

# %%
img = cv2.imread('Images/Opening2.jpg', 0)
_, binary = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

kernel = np.ones((45, 45), np.uint8)
closing = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(binary, 'gray')
plt.title('Original')
plt.subplot(1, 2, 2)
plt.imshow(closing, 'gray')
plt.title('After Closing')
plt.show()

# %%
img = cv2.imread('Images/BoundaryExtraction.jpg', 0)
_, binary = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

kernel = np.ones((3, 3), np.uint8)

gradient = cv2.morphologyEx(binary, cv2.MORPH_GRADIENT, kernel)

eroded = cv2.erode(binary, kernel)
internal = cv2.subtract(binary, eroded)

dilated = cv2.dilate(binary, kernel)
external = cv2.subtract(dilated, binary)

titles = ['Original', 'Gradient', 'Internal', 'External']
images = [binary, gradient, internal, external]

plt.figure(figsize=(12, 4))
for i in range(4):
    plt.subplot(1, 4, i + 1)
    plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.axis('off')
plt.show()
