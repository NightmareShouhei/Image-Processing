# %%
# Hamza Hashim Alsihati
# 2230006810
# 8MA1
# Image Processing

# %%
# Display image
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('Images/cameraman.tif')
plt.imshow(img)
plt.show()

# %%
# Display image
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.cm as cm
img2 = Image.open('Images/lena.tif')
plt.imshow(img2, cmap = cm.Greys_r)
plt.show()

# %%
# Save/Write images
cv2.imwrite('Images/new_image.jpg', img)
img2.save('Images/new_image2.jpg')

# %%
import numpy as np
print(img.shape)
print(img)

# Convert the image to a NumPy array
img_array = np.array(img2)

# Print the array
print(img_array.shape)
print(img_array)
# Out:
# (256, 256, 3)
# [[[156 156 156]
#   [159 159 159]
#   [158 158 158]
#   ...
#   [151 151 151]
#   [152 152 152]
#   [152 152 152]]
#
#  [[160 160 160]
#   [154 154 154]
#   [157 157 157]
#   ...
#   [154 154 154]
#   [155 155 155]
#   [153 153 153]]
#
#  [[156 156 156]
#   [159 159 159]
#   [158 158 158]
#   ...
#   [151 151 151]
#   [152 152 152]
#   [152 152 152]]
#
#  ...
#
#  [[114 114 114]
#   [132 132 132]
#   [123 123 123]
#   ...
#   [135 135 135]
#   [137 137 137]
#   [114 114 114]]
#
#  [[121 121 121]
#   [126 126 126]
#   [130 130 130]
#   ...
#   [133 133 133]
#   [130 130 130]
#   [113 113 113]]
#
#  [[121 121 121]
#   [126 126 126]
#   [130 130 130]
#   ...
#   [133 133 133]
#   [130 130 130]
#   [113 113 113]]]
# (256, 256)
# [[137 136 133 ... 145 148 114]
#  [137 136 133 ... 145 148 114]
#  [138 133 134 ... 133 125  87]
#  ...
#  [ 28  28  29 ...  53  62  59]
#  [ 20  25  26 ...  64  69  65]
#  [ 22  30  25 ...  71  68  72]]
